ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_vine_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_seize_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_size_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_death_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_thought_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_learn_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_wife_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_search_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bought_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_jail_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_make_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mode_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bite_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_when_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_take_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pool_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_tool_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_wire_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chief_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_vote_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_lot_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_gaze_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_back_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_kill_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bath_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sure_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_white_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_haze_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_raise_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_far_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_wash_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ditch_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dead_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_which_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_week_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_book_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_thumb_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_calm_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dog_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_goal_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pick_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hire_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_knock_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rough_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sail_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_keep_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_life_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rose_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ripe_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_gin_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hash_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_five_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_south_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_third_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chain_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_lid_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_germ_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_juice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_cool_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_have_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_late_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_love_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dime_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_gun_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pole_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pike_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_near_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_yearn_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_cause_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_young_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pad_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_turn_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_home_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rot_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pain_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_tire_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_match_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hall_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_king_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_name_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_wheat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_peg_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_team_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hurl_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_doll_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_kick_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_half_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_wag_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_met_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_deep_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_cab_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_whip_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shout_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_nag_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_cheek_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_such_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_jug_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ton_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_thin_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shack_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_door_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_phone_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shall_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sheep_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mill_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_food_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_tough_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_reach_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_date_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mop_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_loaf_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_judge_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chalk_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_youth_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_perch_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_jar_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_should_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_keen_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_lean_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_soup_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dip_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_talk_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_neat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bean_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_good_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bar_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_fat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dab_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mob_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pearl_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_room_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_yes_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hate_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rain_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_check_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_numb_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_fit_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chair_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hole_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_moon_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_nice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ring_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_read_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_keg_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sell_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_puff_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bone_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_void_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hit_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_goose_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_came_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_limb_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pass_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_kite_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_voice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mood_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mess_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_gap_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_laud_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_choice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_witch_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shawl_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_time_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_road_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_boat_ps.wav

# %%
#Source
# https://learnpython.com/blog/plot-waveform-in-python/

# %%
#Wave is the library to read and write audio files
import wave

wav_obj = wave.open('/kaggle/input/speech-emotion-recognition-en/Ravdess/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-02-22.wav','rb')
sample_freq = wav_obj.getframerate()
# number of frames per second
print(sample_freq)
# Out:
# 48000

# %%
#Getting the number of frames in the audio file
n_samples = wav_obj.getnframes()
# number of frames
print(n_samples)
# Out:
# 179379

# %%
t_audio = n_samples/sample_freq
# duration of audio clip in seconds
print(t_audio)
# Out:
# 3.7370625

# %%
# finding number of channels
n_channels = wav_obj.getnchannels()
print(n_channels)
# Out:
# 1

# %%
#gathering signals from the audio file
wave_signal = wav_obj.readframes(n_samples)

# %%
#array of frame data from audio
signals = np.frombuffer(wave_signal, dtype=np.int16)

# %%
#printing the signals shape
print(signals.shape)
# Out:
# (179379,)

# %%
#linearly spaced values
times = np.linspace(0, n_samples/sample_freq, num=n_samples)

# %%
import matplotlib.pyplot as plt

# %%
#Visualisation of the audio file
plt.figure(figsize=(15,5))
plt.plot(times,signals)
plt.title('Visualization of audio file')
plt.xlabel('Time (s)')
plt.ylabel('Signal value')
plt.xlim(0,t_audio)
plt.show()
